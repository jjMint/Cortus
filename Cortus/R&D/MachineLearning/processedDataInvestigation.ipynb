# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sys
import seaborn as sns


np.set_printoptions(threshold=sys.maxsize)

# %%
finalFrame = pd.read_pickle("C:\Users\jshke\Desktop\dbchange\datasetfinal.pkl")
finalFrame = finalFrame.dropna(axis=1, how='all')
finalFrame = finalFrame.fillna(0)
datasetLabels = finalFrame[['processType']]
finalFrame
# Out:
#     processType     binsz  bits  machine                               os  \
# 0        benign  57472787     0        1  Windows NT Workstation 6.1.7601
# 1        benign  57472787     0        1  Windows NT Workstation 6.1.7601
# 2        benign  57341667     0        1  Windows NT Workstation 6.1.7601
# 3        benign  57341571     0        1  Windows NT Workstation 6.1.7601
# 4        benign  57341619     0        1  Windows NT Workstation 6.1.7601
# ..          ...       ...   ...      ...                              ...
# 594   malicious  85181688     0        1  Windows NT Workstation 6.1.7601
# 595   malicious  52342676     0        1  Windows NT Workstation 6.1.7601
# 596   malicious  29612378     1        0  Windows NT Workstation 6.1.7601
# 597   malicious  29612274     1        0  Windows NT Workstation 6.1.7601
# 598   malicious  20315170     0        1  Windows NT Workstation 6.1.7601
#
#     rpath  static  streams subsys    va  ... permissionCount_4  \
# ...

# %%
finalFrame = finalFrame[finalFrame.T[finalFrame.dtypes!=np.object].index]
finalFrame = pd.concat([finalFrame, datasetLabels])

finalFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1797 entries, 0 to 598
# Data columns (total 40 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   binsz                           599 non-null    float64
#  1   bits                            599 non-null    float64
#  2   machine                         599 non-null    float64
#  3   static                          599 non-null    float64
#  4   streams                         599 non-null    float64
#  5   fd                              599 non-null    float64
#  6   size                            599 non-null    float64
#  7   minopsz                         599 non-null    float64
#  8   maxopsz                         599 non-null    float64
#  9   invopsz                         599 non-null    float64
#  10  block                           599 non-null    float64
#  11  eip                             599 non-null    float64
# ...

# %%
sns.pairplot(data = finalFrame, hue='processType', palette='RdBu')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jshke\Documents\Cortus\Cortus\Cortus\R&D\MachineLearning\processedDataInvestigation.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jshke/Documents/Cortus/Cortus/Cortus/R%26D/MachineLearning/processedDataInvestigation.ipynb#ch0000003?line=0'>1</a> sns.pairplot(data = finalFrame, hue='processType', palette='RdBu')
#
# File c:\Users\jshke\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      <a href='file:///c%3A/Users/jshke/AppData/Local/Programs/Python/Python310/lib/site-packages/seaborn/_decorators.py?line=35'>36</a>     warnings.warn(
# ...
